# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from sklearn.preprocessing import StandardScaler,MinMaxScaler,RobustScaler
from sklearn.preprocessing import LabelEncoder

# %%
pip install plotly

# %% [markdown]
# Data collection and loading

# %%
df=pd.read_csv("/content/Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# DATA ANALYSIS

# %% [markdown]
# prescriptive analysis

# %%
df.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
df.tail(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 140  141            6.7           3.1            5.6           2.4
# 141  142            6.9           3.1            5.1           2.3
# 142  143            5.8           2.7            5.1           1.9
# 143  144            6.8           3.2            5.9           2.3
# 144  145            6.7           3.3            5.7           2.5
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 140  Iris-virginica
# 141  Iris-virginica
# 142  Iris-virginica
# 143  Iris-virginica
# 144  Iris-virginica
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# ...

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df['PetalLengthCm']
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: PetalLengthCm, Length: 150, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.shape
# Out:
# (150, 6)

# %% [markdown]
# Statistical Analysis

# %%
df['SepalLengthCm'].mean()
# Out:
# np.float64(5.843333333333334)

# %%
df['PetalLengthCm'].median()
# Out:
# 4.35

# %%
df['PetalWidthCm'].mode()
# Out:
# 0    0.2
# Name: PetalWidthCm, dtype: float64

# %%
df['SepalWidthCm'].std()
# Out:
# 0.4335943113621737

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# DATA VISUALAIZATION 1D

# %% [markdown]
# Histogram

# %%
plt.hist(df['SepalLengthCm'],color='red',edgecolor='black')
plt.title('Frequency of sepallength')
plt.xlabel('Sepallength')
plt.ylabel('Frequency')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Pie chart

# %%
plt.pie(df['PetalLengthCm'])
plt.show()

# %% [markdown]
# KDE plot

# %%
sns.kdeplot(df['PetalWidthCm'],fill=True)
plt.show()

# %% [markdown]
# Boxplot

# %%
sns.boxplot(df['SepalWidthCm'])
plt.show()

# %% [markdown]
# 2D visualization

# %% [markdown]
# Bar chart

# %%
plt.bar(df['SepalWidthCm'],df['SepalLengthCm'],color='pink')
plt.title('SepalWidthCm vs SepalLengthCm')
plt.xlabel('SepalWidthCm')
plt.ylabel('SepalLengthCm')
plt.show()

# %% [markdown]
# Scatter plot

# %%
plt.scatter(df['PetalLengthCm'],df['PetalWidthCm'],color='green')
plt.title('PetalLengthCm vs PetalWidthCm')
plt.xlabel('PetalLengthCm')
plt.ylabel('PetalWidthCm')
plt.grid(True)
plt.show()

# %% [markdown]
# Line plot

# %%
plt.plot(df['PetalLengthCm'],df['SepalWidthCm'],marker='o',linestyle='--',color='orange')
plt.title('PetalLengthCm vs SepallWidthCm')
plt.xlabel('PetalLengthCm')
plt.ylabel('SepalWidthCm')
plt.show()

# %% [markdown]
# Stacked Bar chart

# %%
plt.bar(df['PetalLengthCm'],df['SepalWidthCm'],label='Group 1',color='blue')
plt.bar(df['SepalLengthCm'],df['PetalWidthCm'],bottom=df['PetalLengthCm'],label='Group 2',color='pink')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Stacked Bar Chart')
plt.legend()
plt.show()

# %% [markdown]
# 3D visualization

# %%
x=df['PetalLengthCm']
y=df['PetalWidthCm']
z=df['SepalLengthCm']
fig=go.Figure(data=[go.Scatter3d(
    x=x,y=y,z=z,
    marker=dict(size=5,color='yellow',colorscale='Viridis'),
    line=dict(color='black',width=3)
)])
fig.update_layout(title='3D Scatter Plot')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df=df.drop(columns='Species')

# %% [markdown]
# Preprocessing

# %%
ss=StandardScaler()
df_ss=pd.DataFrame(ss.fit_transform(df))

# %%
df_ss
# Out:
#             0         1         2         3         4
# 0   -1.720542 -0.900681  1.032057 -1.341272 -1.312977
# 1   -1.697448 -1.143017 -0.124958 -1.341272 -1.312977
# 2   -1.674353 -1.385353  0.337848 -1.398138 -1.312977
# 3   -1.651258 -1.506521  0.106445 -1.284407 -1.312977
# 4   -1.628164 -1.021849  1.263460 -1.341272 -1.312977
# ..        ...       ...       ...       ...       ...
# 145  1.628164  1.038005 -0.124958  0.819624  1.447956
# 146  1.651258  0.553333 -1.281972  0.705893  0.922064
# 147  1.674353  0.795669 -0.124958  0.819624  1.053537
# 148  1.697448  0.432165  0.800654  0.933356  1.447956
# 149  1.720542  0.068662 -0.124958  0.762759  0.790591
#
# [150 rows x 5 columns]

# %%
mm=MinMaxScaler()
df_mm=pd.DataFrame(mm.fit_transform(df))

# %%
df_mm
# Out:
#             0         1         2         3         4
# 0    0.000000  0.222222  0.625000  0.067797  0.041667
# 1    0.006711  0.166667  0.416667  0.067797  0.041667
# 2    0.013423  0.111111  0.500000  0.050847  0.041667
# 3    0.020134  0.083333  0.458333  0.084746  0.041667
# 4    0.026846  0.194444  0.666667  0.067797  0.041667
# ..        ...       ...       ...       ...       ...
# 145  0.973154  0.666667  0.416667  0.711864  0.916667
# 146  0.979866  0.555556  0.208333  0.677966  0.750000
# 147  0.986577  0.611111  0.416667  0.711864  0.791667
# 148  0.993289  0.527778  0.583333  0.745763  0.916667
# 149  1.000000  0.444444  0.416667  0.694915  0.708333
#
# [150 rows x 5 columns]

# %%
rs=RobustScaler()
df_rs=pd.DataFrame(rs.fit_transform(df))

# %%
df_rs
# Out:
#             0         1    2         3         4
# 0   -1.000000 -0.538462  1.0 -0.842857 -0.733333
# 1   -0.986577 -0.692308  0.0 -0.842857 -0.733333
# 2   -0.973154 -0.846154  0.4 -0.871429 -0.733333
# 3   -0.959732 -0.923077  0.2 -0.814286 -0.733333
# 4   -0.946309 -0.615385  1.2 -0.842857 -0.733333
# ..        ...       ...  ...       ...       ...
# 145  0.946309  0.692308  0.0  0.242857  0.666667
# 146  0.959732  0.384615 -1.0  0.185714  0.400000
# 147  0.973154  0.538462  0.0  0.242857  0.466667
# 148  0.986577  0.307692  0.8  0.300000  0.666667
# 149  1.000000  0.076923  0.0  0.214286  0.333333
#
# [150 rows x 5 columns]

# %% [markdown]
# Z score value

# %%
z_scores=np.abs((df-df.mean())/df.std())

# %%
z_scores
# Out:
#            Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0    1.714797       0.897674      1.028611       1.336794      1.308593
# 1    1.691780       1.139200      0.124540       1.336794      1.308593
# 2    1.668762       1.380727      0.336720       1.393470      1.308593
# 3    1.645745       1.501490      0.106090       1.280118      1.308593
# 4    1.622728       1.018437      1.259242       1.336794      1.308593
# ..        ...            ...           ...            ...           ...
# 145  1.622728       1.034539      0.124540       0.816888      1.443121
# 146  1.645745       0.551486      1.277692       0.703536      0.918985
# 147  1.668762       0.793012      0.124540       0.816888      1.050019
# 148  1.691780       0.430722      0.797981       0.930239      1.443121
# 149  1.714797       0.068433      0.124540       0.760212      0.787951
#
# [150 rows x 5 columns]

# %%
df_outliers_removed=df[(z_scores<3).all(axis=1)]

# %%
df_outliers_removed
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
# [149 rows x 5 columns]

# %% [markdown]
# Feature Engineering

# %%
df['Sepal']=df['SepalLengthCm']*df['SepalWidthCm']

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Sepal
# 0      1            5.1           3.5            1.4           0.2  17.85
# 1      2            4.9           3.0            1.4           0.2  14.70
# 2      3            4.7           3.2            1.3           0.2  15.04
# 3      4            4.6           3.1            1.5           0.2  14.26
# 4      5            5.0           3.6            1.4           0.2  18.00
# ..   ...            ...           ...            ...           ...    ...
# 145  146            6.7           3.0            5.2           2.3  20.10
# 146  147            6.3           2.5            5.0           1.9  15.75
# 147  148            6.5           3.0            5.2           2.0  19.50
# 148  149            6.2           3.4            5.4           2.3  21.08
# 149  150            5.9           3.0            5.1           1.8  17.70
#
# [150 rows x 6 columns]

# %% [markdown]
# Label Encoder

# %%
le=LabelEncoder()
df['Species']=le.fit_transform(df['Species'])
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]
